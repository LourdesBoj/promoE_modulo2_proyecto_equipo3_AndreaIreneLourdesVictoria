# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../ficheros/dataframe_estudio.csv', index_col = 0)
df.shape
# Out:
# (2297, 10)

# %%
df.head(2)
# Out:
#                      country  current_role yearly_compensation  \
# 16                   Belgium  Data Analyst         2,000-2,999
# 32  United States of America  Data Analyst             unknown
#
#    programming_languages                                               ides  \
# 16           Python, SQL  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 32                     R                                           RStudio
#
#                                      visualization  \
# 16   Matplotlib ,Seaborn ,Plotly / Plotly Express
# 32                               Ggplot / ggplot2
#
#                                            activities     gender  \
# 16  Analyze and understand data to influence produ...        Man
# 32                                            unknown  Nonbinary
#
#                                          primary_tool     ages
# 16  Local development environments (RStudio, Jupyt...  mediana
# 32                                            unknown    joven

# %% [markdown]
# ## ¿Cuáles son los entornos de desarrollo en los que más se trabaja?

# %%
df['ides'].unique()
# Out:
# array(['Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Jupyter Notebook',
#        'RStudio ', ' Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm ,MATLAB ,Jupyter Notebook',
#        'RStudio ,Jupyter Notebook', 'PyCharm , Spyder', ' None',
#        'Jupyter Notebook, Other', 'Visual Studio ,Jupyter Notebook',
#        'Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,PyCharm , Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Spyder',
#        ' Spyder',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm ,Jupyter Notebook',
#        'Visual Studio ', 'PyCharm ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ',
#        'Visual Studio Code (VSCode) , Notepad++,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,Jupyter Notebook',
#        'RStudio ,PyCharm ,MATLAB ',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm ,Jupyter Notebook',
#        'unknown', ' Spyder, Other', ' Notepad++',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm ,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ',
#        'Visual Studio Code (VSCode) , Spyder,Jupyter Notebook',
#        ' Notepad++, Vim / Emacs', 'PyCharm ',
#        'RStudio ,Visual Studio ,PyCharm ,Jupyter Notebook',
#        'PyCharm , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm ',
#        'RStudio ,Visual Studio Code (VSCode) ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Notepad++, Vim / Emacs,Jupyter Notebook',
#        'Visual Studio ,PyCharm ,MATLAB ',
#        'RStudio ,Visual Studio , Notepad++', 'RStudio ,Visual Studio ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Sublime Text,Jupyter Notebook',
#        'PyCharm , Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm ,Jupyter Notebook',
#        'PyCharm , Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Notepad++,MATLAB ,Jupyter Notebook',
#        'RStudio , Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,PyCharm ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Notepad++,Jupyter Notebook',
#        'RStudio ,Jupyter Notebook, Other',
#        'Visual Studio ,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder,MATLAB ,Jupyter Notebook',
#        ' Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Notepad++,Jupyter Notebook',
#        ' Spyder,Jupyter Notebook',
#        'Visual Studio , Sublime Text,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,PyCharm ,Jupyter Notebook',
#        'MATLAB ',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Notepad++',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Notepad++,Jupyter Notebook',
#        'RStudio , Spyder, Notepad++,Jupyter Notebook', ' Other',
#        'Visual Studio ,Visual Studio Code (VSCode) ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm ',
#        'Visual Studio ,Visual Studio Code (VSCode) ,PyCharm ,Jupyter Notebook',
#        'RStudio ,Visual Studio ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Notepad++, Sublime Text,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Spyder,Jupyter Notebook',
#        'PyCharm , Notepad++,Jupyter Notebook', ' Spyder, Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm , Spyder,Jupyter Notebook',
#        'RStudio ,PyCharm ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) , Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Spyder',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Spyder, Notepad++,Jupyter Notebook',
#        ' Spyder, Notepad++',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Vim / Emacs,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,PyCharm , Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++, Sublime Text, Vim / Emacs,MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm , Sublime Text,Jupyter Notebook',
#        'Visual Studio ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio , Spyder, Vim / Emacs,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,PyCharm , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio , Spyder,Jupyter Notebook',
#        'PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Sublime Text,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio , Notepad++,MATLAB ,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,PyCharm , Sublime Text,Jupyter Notebook',
#        ' Sublime Text,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm ,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ',
#        'RStudio , Spyder,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Sublime Text,Jupyter Notebook',
#        ' Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Notepad++,Jupyter Notebook',
#        'PyCharm , Notepad++,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Notepad++, Vim / Emacs',
#        'Visual Studio Code (VSCode) ,PyCharm , Sublime Text,MATLAB ',
#        'Visual Studio Code (VSCode) ,Jupyter Notebook, Other',
#        'Visual Studio ,Jupyter Notebook, Other',
#        'Visual Studio , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,MATLAB ,Jupyter Notebook',
#        'Visual Studio ,PyCharm , Sublime Text,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) ,PyCharm ',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Spyder,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) , Sublime Text,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) ,MATLAB ',
#        'Visual Studio Code (VSCode) ,PyCharm ',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Notepad++, Sublime Text,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Notepad++, Vim / Emacs,Jupyter Notebook',
#        'PyCharm ,Jupyter Notebook, Other', 'RStudio ,PyCharm ',
#        'RStudio ,Visual Studio , Spyder,MATLAB ,Jupyter Notebook',
#        'Visual Studio ,PyCharm , Notepad++,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) , Notepad++,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Spyder,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm , Spyder',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Notepad++',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ,PyCharm , Spyder',
#        ' Notepad++, Other', 'RStudio ,Visual Studio Code (VSCode) ',
#        'Visual Studio , Notepad++, Sublime Text',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,Jupyter Notebook, Other',
#        'Visual Studio Code (VSCode) ,MATLAB ,Jupyter Notebook',
#        'RStudio , Notepad++,Jupyter Notebook',
#        'MATLAB ,Jupyter Notebook, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Sublime Text',
#        ' Spyder, Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) , Notepad++,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) , Notepad++',
#        'Visual Studio ,PyCharm ,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'RStudio ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) , Spyder,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm , Notepad++,Jupyter Notebook',
#        'Visual Studio , Notepad++, Sublime Text,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) , Notepad++, Sublime Text',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Spyder, Notepad++,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Sublime Text',
#        'RStudio ,Visual Studio , Spyder',
#        'Visual Studio ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Spyder, Notepad++,Jupyter Notebook',
#        'Visual Studio , Other',
#        ' Sublime Text, Vim / Emacs,Jupyter Notebook, Other',
#        'Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter Notebook',
#        'RStudio ,PyCharm , Spyder,Jupyter Notebook',
#        'PyCharm , Sublime Text,MATLAB ,Jupyter Notebook',
#        'Visual Studio , Notepad++',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Notepad++',
#        'Visual Studio Code (VSCode) ,PyCharm , Spyder,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,PyCharm , Notepad++, Sublime Text,Jupyter Notebook',
#        'Visual Studio , Sublime Text',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Jupyter Notebook, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Vim / Emacs,Jupyter Notebook',
#        'RStudio ,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) ,Jupyter Notebook',
#        ' Vim / Emacs,Jupyter Notebook',
#        'Visual Studio ,PyCharm , Notepad++',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Notepad++,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Sublime Text,Jupyter Notebook',
#        ' Spyder,MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) , Spyder',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,MATLAB ',
#        'PyCharm , Notepad++',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Spyder,Jupyter Notebook',
#        ' Sublime Text, Vim / Emacs,Jupyter Notebook',
#        'RStudio ,Visual Studio ,PyCharm , Notepad++, Sublime Text,Jupyter Notebook',
#        'RStudio ,PyCharm , Other', 'PyCharm , Sublime Text',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++,Jupyter Notebook',
#        'RStudio ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ',
#        'Visual Studio ,PyCharm ',
#        'RStudio ,PyCharm , Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm , Sublime Text',
#        'RStudio , Notepad++,Jupyter Notebook, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Spyder,MATLAB ,Jupyter Notebook',
#        'RStudio , Notepad++, Other',
#        'Visual Studio Code (VSCode) , Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) , Spyder, Notepad++, Sublime Text',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm ,MATLAB ',
#        'RStudio ,PyCharm , Notepad++',
#        'Visual Studio Code (VSCode) , Notepad++,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Notepad++, Sublime Text, Vim / Emacs,Jupyter Notebook',
#        'RStudio ,Visual Studio ,PyCharm ',
#        'RStudio , Spyder,Jupyter Notebook, Other',
#        'Visual Studio Code (VSCode) , Notepad++',
#        'PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter Notebook, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio , Spyder',
#        ' Notepad++, Sublime Text', 'RStudio ,MATLAB ,Jupyter Notebook',
#        'RStudio ,PyCharm , Spyder, Notepad++,MATLAB ,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,PyCharm , Spyder,Jupyter Notebook, Other',
#        'Visual Studio Code (VSCode) ,PyCharm , Sublime Text,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm , Spyder,MATLAB ,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,PyCharm , Notepad++, Sublime Text,Jupyter Notebook',
#        'RStudio , Notepad++,MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio , Notepad++,Jupyter Notebook',
#        'RStudio , Notepad++',
#        'RStudio , Spyder, Notepad++, Sublime Text,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio , Vim / Emacs,Jupyter Notebook',
#        'RStudio ,PyCharm , Sublime Text,Jupyter Notebook',
#        'RStudio ,PyCharm , Spyder', 'RStudio , Spyder',
#        'RStudio ,PyCharm , Notepad++, Sublime Text',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Spyder, Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++, Sublime Text, Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++, Sublime Text,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Spyder, Sublime Text,Jupyter Notebook',
#        ' Sublime Text',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,PyCharm ',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm ',
#        'RStudio ,PyCharm ,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Spyder, Sublime Text',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++, Sublime Text',
#        'Visual Studio ,Visual Studio Code (VSCode) , Other',
#        'Visual Studio ,PyCharm , Notepad++, Vim / Emacs,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Notepad++, Vim / Emacs,Jupyter Notebook',
#        'RStudio , Spyder, Notepad++',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Notepad++,Jupyter Notebook, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Notepad++',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Spyder, Notepad++, Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Spyder,Jupyter Notebook',
#        'Visual Studio ,PyCharm , Notepad++,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,MATLAB ,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Notepad++,Jupyter Notebook',
#        'RStudio , Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,Jupyter Notebook',
#        'RStudio ,Visual Studio , Notepad++, Sublime Text, Vim / Emacs,Jupyter Notebook',
#        ' Spyder, Notepad++, Sublime Text',
#        'RStudio ,PyCharm , Sublime Text, Vim / Emacs,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) ,MATLAB ,Jupyter Notebook',
#        'Visual Studio ,MATLAB ', 'PyCharm ,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Notepad++,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Sublime Text,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Notepad++, Sublime Text, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Spyder,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Sublime Text',
#        'Visual Studio Code (VSCode) , Spyder',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Sublime Text',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++,MATLAB ,Jupyter Notebook',
#        ' Notepad++,Jupyter Notebook, Other',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Notepad++,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Spyder, Sublime Text,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++,Jupyter Notebook, Other',
#        'RStudio , Sublime Text',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Sublime Text',
#        'PyCharm , Vim / Emacs,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Notepad++, Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Notepad++,MATLAB ,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Vim / Emacs',
#        'Visual Studio Code (VSCode) , Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Spyder, Sublime Text,Jupyter Notebook',
#        'PyCharm , Notepad++,MATLAB ', 'PyCharm , Notepad++, Other',
#        'RStudio , Spyder, Notepad++, Vim / Emacs,Jupyter Notebook',
#        'RStudio , Vim / Emacs',
#        'RStudio ,Visual Studio Code (VSCode) , Sublime Text,Jupyter Notebook',
#        ' Notepad++, Vim / Emacs, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Notepad++',
#        'Visual Studio Code (VSCode) ,PyCharm ,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,PyCharm , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ,MATLAB ,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Notepad++,MATLAB ',
#        'RStudio ,Visual Studio Code (VSCode) , Spyder,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Sublime Text,Jupyter Notebook, Other',
#        ' Sublime Text, Vim / Emacs,MATLAB ,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Sublime Text',
#        'RStudio , Spyder,MATLAB ',
#        'RStudio , Notepad++, Sublime Text, Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++, Sublime Text,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,PyCharm ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Spyder, Vim / Emacs,Jupyter Notebook',
#        'RStudio , Spyder,MATLAB ,Jupyter Notebook',
#        'RStudio , Sublime Text, Vim / Emacs,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio ,PyCharm , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++, Sublime Text, Vim / Emacs,Jupyter Notebook',
#        'Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ,PyCharm , Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio , Spyder,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio , Notepad++, Sublime Text,Jupyter Notebook',
#        ' Spyder, Sublime Text,Jupyter Notebook',
#        ' Spyder,Jupyter Notebook, Other',
#        'Visual Studio Code (VSCode) , Notepad++, Sublime Text',
#        'PyCharm , Notepad++, Vim / Emacs,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Spyder, Notepad++,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Sublime Text, Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm ,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Notepad++',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Spyder, Notepad++, Sublime Text',
#        'Visual Studio , Vim / Emacs,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm ,MATLAB ',
#        'Visual Studio ,PyCharm ,Jupyter Notebook, Other',
#        'Visual Studio , Notepad++,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Vim / Emacs',
#        ' Notepad++,MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++, Sublime Text,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'Visual Studio ,PyCharm , Spyder,Jupyter Notebook',
#        'RStudio ,Visual Studio , Spyder, Notepad++',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Spyder, Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm , Sublime Text,Jupyter Notebook',
#        'PyCharm , Notepad++, Sublime Text,MATLAB ,Jupyter Notebook',
#        'PyCharm , Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,PyCharm , Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Vim / Emacs,Jupyter Notebook',
#        'RStudio ,Visual Studio ,PyCharm , Sublime Text,Jupyter Notebook',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Spyder,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Vim / Emacs',
#        'Visual Studio ,Visual Studio Code (VSCode) , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio ,PyCharm , Spyder,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) , Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,PyCharm , Spyder,Jupyter Notebook',
#        'RStudio , Spyder, Notepad++,MATLAB ,Jupyter Notebook',
#        'RStudio , Spyder, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio Code (VSCode) ,PyCharm , Vim / Emacs,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Sublime Text,MATLAB ',
#        'RStudio , Spyder, Notepad++, Sublime Text,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) , Spyder, Notepad++,Jupyter Notebook',
#        'PyCharm , Sublime Text, Vim / Emacs,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm , Sublime Text, Vim / Emacs,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Spyder,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Vim / Emacs,Jupyter Notebook',
#        'Visual Studio , Notepad++,MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) , Other',
#        'Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) , Notepad++',
#        'RStudio ,PyCharm , Vim / Emacs,Jupyter Notebook',
#        'Visual Studio ,PyCharm ,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Notepad++, Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Sublime Text',
#        'RStudio , Vim / Emacs,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Sublime Text,MATLAB ,Jupyter Notebook',
#        'Visual Studio , Notepad++, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'RStudio ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Sublime Text,MATLAB ,Jupyter Notebook',
#        'Visual Studio Code (VSCode) ,PyCharm , Vim / Emacs,Jupyter Notebook',
#        ' Vim / Emacs',
#        'Visual Studio Code (VSCode) ,PyCharm , Sublime Text',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,PyCharm , Notepad++, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Sublime Text',
#        ' Spyder, Notepad++,MATLAB ', 'RStudio ,PyCharm , Sublime Text',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Spyder, Other',
#        ' Sublime Text,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,PyCharm , Spyder,Jupyter Notebook, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) , Notepad++, Sublime Text,MATLAB , Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Spyder, Sublime Text,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) , Spyder,MATLAB ',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,MATLAB ,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter Notebook',
#        'Visual Studio Code (VSCode) , Spyder,MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) , Notepad++, Vim / Emacs,Jupyter Notebook',
#        'RStudio ,Visual Studio Code (VSCode) ,PyCharm , Notepad++, Sublime Text, Vim / Emacs,Jupyter Notebook',
#        'RStudio ,Visual Studio , Notepad++, Other',
#        'PyCharm , Sublime Text, Other',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm , Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Notepad++, Sublime Text',
#        'PyCharm , Spyder, Vim / Emacs,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio , Spyder, Notepad++, Vim / Emacs',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,PyCharm , Spyder, Sublime Text,Jupyter Notebook',
#        'Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,Visual Studio ,PyCharm ,Jupyter Notebook',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Notepad++, Vim / Emacs'],
#       dtype=object)

# %%
#df["ides"] = df["ides"].replace("^Jupyter[A-Za-z(,\s)]*$","Jupyter", regex = True)
df["ides"] = df["ides"].replace("\([A-Za-z(,\s)]*\)","", regex = True)
df["ides"] = df["ides"].replace("Jupyter Notebook","Jupyter", regex = True)

# %%
df['ides'].unique()
# Out:
# array(['Jupyter  ,Jupyter', 'RStudio ', ' Notepad++,Jupyter',
#        'Jupyter  ,PyCharm ,MATLAB ,Jupyter', 'RStudio ,Jupyter',
#        'PyCharm , Spyder', ' None', 'Jupyter, Other',
#        'Visual Studio ,Jupyter', 'Jupyter',
#        'Jupyter  ,Visual Studio ,PyCharm , Notepad++,Jupyter',
#        'Jupyter  ,RStudio , Spyder', ' Spyder',
#        'Jupyter  ,PyCharm ,Jupyter', 'Visual Studio ', 'PyCharm ,Jupyter',
#        'Jupyter  ,RStudio ,PyCharm , Spyder, Sublime Text,Jupyter',
#        'Visual Studio Code  ', 'Visual Studio Code  , Notepad++,Jupyter',
#        'Visual Studio Code  ,Jupyter', 'RStudio ,PyCharm ,MATLAB ',
#        'RStudio ,Visual Studio ,Visual Studio Code  ,PyCharm ,Jupyter',
#        'unknown', ' Spyder, Other', ' Notepad++',
#        'Jupyter  ,RStudio ,PyCharm , Spyder, Notepad++,Jupyter',
#        'Jupyter  ,PyCharm ,MATLAB ', 'Jupyter  ',
#        'Visual Studio Code  , Spyder,Jupyter', ' Notepad++, Vim / Emacs',
#        'PyCharm ', 'RStudio ,Visual Studio ,PyCharm ,Jupyter',
#        'PyCharm , Spyder,Jupyter', 'Jupyter  ,PyCharm ',
#        'RStudio ,Visual Studio Code  ,Jupyter',
#        'Jupyter  , Notepad++, Vim / Emacs,Jupyter',
#        'Visual Studio ,PyCharm ,MATLAB ',
#        'RStudio ,Visual Studio , Notepad++', 'RStudio ,Visual Studio ',
#        'Jupyter  , Sublime Text,Jupyter',
#        'PyCharm , Sublime Text,Jupyter',
#        'Jupyter  ,PyCharm , Notepad++, Sublime Text,Jupyter',
#        'Jupyter  , Notepad++,Jupyter', 'PyCharm , Other',
#        'Jupyter  ,Visual Studio ,PyCharm , Spyder, Notepad++,Jupyter',
#        'Jupyter  ,PyCharm , Notepad++,MATLAB ,Jupyter',
#        'RStudio , Sublime Text,Jupyter',
#        'Jupyter  ,RStudio ,Visual Studio ,PyCharm ',
#        'RStudio ,Jupyter, Other', 'Visual Studio ,MATLAB ,Jupyter',
#        'Jupyter  ,PyCharm , Spyder,MATLAB ,Jupyter',
#        ' Sublime Text,Jupyter', 'Jupyter  ,PyCharm , Notepad++,Jupyter',
#        ' Spyder,Jupyter', 'Visual Studio , Sublime Text,Jupyter',
#        'Visual Studio Code  ,PyCharm ,Jupyter', 'MATLAB ',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Notepad++',
#        'RStudio , Spyder, Notepad++,Jupyter', ' Other',
#        'Visual Studio ,Visual Studio Code  ',
#        'Visual Studio ,Visual Studio Code  ,PyCharm ,Jupyter',
#        'RStudio ,Visual Studio ,Jupyter',
#        'Jupyter  , Notepad++, Sublime Text,MATLAB ,Jupyter',
#        'Jupyter  ,RStudio , Spyder,Jupyter',
#        'PyCharm , Notepad++,Jupyter', ' Spyder, Vim / Emacs',
#        'Jupyter  ,RStudio ',
#        'RStudio ,Visual Studio Code  ,PyCharm , Spyder,Jupyter',
#        'RStudio ,PyCharm ,Jupyter', 'Jupyter  ,RStudio ,Jupyter',
#        'RStudio ,Visual Studio Code  , Notepad++,Jupyter',
#        'Jupyter  , Spyder',
#        'Jupyter  ,RStudio , Spyder, Notepad++,Jupyter',
#        ' Spyder, Notepad++', 'Jupyter  , Vim / Emacs,Jupyter',
#        'Visual Studio Code  ,PyCharm , Notepad++,Jupyter',
#        'Jupyter  ,PyCharm , Spyder, Notepad++, Sublime Text, Vim / Emacs,MATLAB ,Jupyter',
#        'RStudio ,Visual Studio Code  ,PyCharm , Sublime Text,Jupyter',
#        'Visual Studio ,PyCharm , Spyder, Notepad++,Jupyter',
#        'RStudio ,Visual Studio Code  ,PyCharm ,Jupyter',
#        'Jupyter  , Spyder, Notepad++,Jupyter',
#        'RStudio , Spyder, Vim / Emacs,Jupyter',
#        'Visual Studio Code  ,PyCharm , Spyder,Jupyter',
#        'Jupyter  ,Visual Studio , Spyder,Jupyter',
#        'PyCharm , Spyder, Sublime Text,Jupyter',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Sublime Text,Jupyter',
#        'Visual Studio Code  ,PyCharm , Spyder, Sublime Text,Jupyter',
#        'MATLAB ,Jupyter',
#        'RStudio ,Visual Studio , Notepad++,MATLAB ,Jupyter',
#        'Visual Studio Code  ,PyCharm , Sublime Text,Jupyter',
#        ' Sublime Text,MATLAB ,Jupyter',
#        'Jupyter  ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter',
#        'Jupyter  ,RStudio ,PyCharm ,Jupyter',
#        'Visual Studio ,Visual Studio Code  ,PyCharm , Notepad++, Sublime Text,Jupyter',
#        'RStudio , Spyder,Jupyter', 'Visual Studio Code  , Other',
#        'Jupyter  ,PyCharm , Sublime Text,Jupyter',
#        ' Notepad++, Sublime Text,Jupyter',
#        'Jupyter  ,RStudio , Notepad++,Jupyter',
#        'PyCharm , Notepad++,MATLAB ,Jupyter',
#        'Jupyter  , Notepad++, Vim / Emacs',
#        'Visual Studio Code  ,PyCharm , Sublime Text,MATLAB ',
#        'Visual Studio Code  ,Jupyter, Other',
#        'Visual Studio ,Jupyter, Other', 'Visual Studio , Spyder,Jupyter',
#        'Jupyter  ,RStudio ,MATLAB ,Jupyter',
#        'Visual Studio ,PyCharm , Sublime Text,Jupyter',
#        'Visual Studio ,Visual Studio Code  ,PyCharm ',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Spyder,Jupyter',
#        'Visual Studio ,Visual Studio Code  , Sublime Text,Jupyter',
#        'Visual Studio ,Visual Studio Code  ,MATLAB ',
#        'Visual Studio Code  ,PyCharm ',
#        'RStudio ,Visual Studio ,Visual Studio Code  ,PyCharm , Spyder, Sublime Text,Jupyter',
#        'Visual Studio Code  , Notepad++, Vim / Emacs,Jupyter',
#        'PyCharm ,Jupyter, Other', 'RStudio ,PyCharm ',
#        'RStudio ,Visual Studio , Spyder,MATLAB ,Jupyter',
#        'Visual Studio ,PyCharm , Notepad++,Jupyter',
#        'Visual Studio ,Visual Studio Code  , Notepad++,MATLAB ,Jupyter',
#        'Jupyter  , Spyder,Jupyter',
#        'Visual Studio Code  , Spyder, Notepad++,Jupyter',
#        'RStudio ,Visual Studio Code  ,PyCharm , Spyder',
#        'Jupyter  ,RStudio , Notepad++', 'Jupyter  ,PyCharm , Spyder',
#        ' Notepad++, Other', 'RStudio ,Visual Studio Code  ',
#        'Visual Studio , Notepad++, Sublime Text', 'Jupyter  , Other',
#        'Jupyter  ,Jupyter, Other', 'Visual Studio Code  ,MATLAB ,Jupyter',
#        'RStudio , Notepad++,Jupyter', 'MATLAB ,Jupyter, Other',
#        'Jupyter  , Sublime Text', ' Spyder, Notepad++,Jupyter',
#        'Jupyter  ,RStudio ,Visual Studio ,Jupyter',
#        'Visual Studio ,Visual Studio Code  , Notepad++,Jupyter',
#        'Visual Studio ,Visual Studio Code  , Notepad++',
#        'Visual Studio ,PyCharm ,Jupyter',
#        'Visual Studio ,Visual Studio Code  ,Jupyter',
#        'Jupyter  ,PyCharm , Spyder, Sublime Text,Jupyter',
#        'RStudio ,PyCharm , Spyder, Notepad++,Jupyter',
#        'RStudio ,Visual Studio ,Visual Studio Code  ,PyCharm , Notepad++,Jupyter',
#        'Visual Studio ,Visual Studio Code  , Spyder,MATLAB ',
#        'Jupyter  ,RStudio ,PyCharm , Notepad++,Jupyter',
#        'Visual Studio , Notepad++, Sublime Text,Jupyter',
#        'Visual Studio ,Visual Studio Code  , Notepad++, Sublime Text',
#        'Jupyter  , Spyder, Notepad++,MATLAB ',
#        'RStudio ,Visual Studio , Spyder',
#        'Visual Studio ,PyCharm , Spyder, Sublime Text,Jupyter',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Spyder, Notepad++,Jupyter',
#        'Visual Studio , Other',
#        ' Sublime Text, Vim / Emacs,Jupyter, Other',
#        'Visual Studio Code  ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter',
#        'RStudio ,PyCharm , Spyder,Jupyter',
#        'PyCharm , Sublime Text,MATLAB ,Jupyter',
#        'Visual Studio , Notepad++',
#        'RStudio ,Visual Studio Code  ,PyCharm ', 'Jupyter  , Notepad++',
#        'Visual Studio Code  ,PyCharm , Spyder,MATLAB ,Jupyter',
#        'Jupyter  ,Visual Studio ,PyCharm , Notepad++, Sublime Text,Jupyter',
#        'Visual Studio , Sublime Text', 'RStudio ,MATLAB ',
#        ' Vim / Emacs,Jupyter', 'Visual Studio ,PyCharm , Notepad++',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Notepad++,MATLAB ',
#        'Jupyter  ,MATLAB ', ' Spyder,MATLAB ,Jupyter',
#        'RStudio ,Visual Studio Code  , Spyder',
#        'Jupyter  ,RStudio ,MATLAB ', 'PyCharm , Notepad++',
#        'Jupyter  ,PyCharm , Spyder,Jupyter',
#        ' Sublime Text, Vim / Emacs,Jupyter',
#        'RStudio ,Visual Studio ,PyCharm , Notepad++, Sublime Text,Jupyter',
#        'RStudio ,PyCharm , Other', 'PyCharm , Sublime Text',
#        'RStudio ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter',
#        'Jupyter  ,Visual Studio ', 'Visual Studio ,PyCharm ',
#        'RStudio ,PyCharm , Notepad++,Jupyter',
#        'Jupyter  ,RStudio ,PyCharm , Sublime Text',
#        'RStudio , Notepad++,Jupyter, Other',
#        'Jupyter  , Notepad++, Sublime Text,Jupyter',
#        'Jupyter  , Spyder,MATLAB ,Jupyter', 'RStudio , Notepad++, Other',
#        'Visual Studio Code  , Sublime Text,Jupyter',
#        'Jupyter  , Spyder, Notepad++, Sublime Text',
#        'RStudio ,Visual Studio Code  ,PyCharm ,MATLAB ',
#        'RStudio ,PyCharm , Notepad++',
#        'Visual Studio Code  , Notepad++,MATLAB ,Jupyter',
#        'Jupyter  , Notepad++, Sublime Text, Vim / Emacs,Jupyter',
#        'RStudio ,Visual Studio ,PyCharm ',
#        'RStudio , Spyder,Jupyter, Other',
#        'Visual Studio Code  , Notepad++',
#        'PyCharm , Spyder, Notepad++,Jupyter',
#        'Jupyter  ,PyCharm , Spyder, Notepad++, Sublime Text,Jupyter, Other',
#        'Jupyter  ,Visual Studio , Spyder', ' Notepad++, Sublime Text',
#        'RStudio ,MATLAB ,Jupyter',
#        'RStudio ,PyCharm , Spyder, Notepad++,MATLAB ,Jupyter',
#        'Visual Studio Code  ,PyCharm , Spyder, Notepad++,Jupyter',
#        'RStudio ,PyCharm , Spyder,Jupyter, Other',
#        'Visual Studio Code  ,PyCharm , Sublime Text,MATLAB ,Jupyter',
#        'Jupyter  ,RStudio ,PyCharm , Spyder,MATLAB ,Jupyter',
#        'Visual Studio Code  ,PyCharm , Notepad++, Sublime Text,Jupyter',
#        'RStudio , Notepad++,MATLAB ,Jupyter',
#        'RStudio ,Visual Studio , Notepad++,Jupyter',
#        'RStudio , Notepad++',
#        'RStudio , Spyder, Notepad++, Sublime Text,MATLAB ',
#        'Jupyter  ,Visual Studio , Vim / Emacs,Jupyter',
#        'RStudio ,PyCharm , Sublime Text,Jupyter',
#        'RStudio ,PyCharm , Spyder', 'RStudio , Spyder',
#        'RStudio ,PyCharm , Notepad++, Sublime Text',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Spyder, Notepad++, Sublime Text,Jupyter',
#        'Jupyter  ,PyCharm , Spyder, Notepad++, Sublime Text, Vim / Emacs',
#        'Jupyter  ,PyCharm , Notepad++, Sublime Text,MATLAB ,Jupyter',
#        'Jupyter  ,RStudio , Spyder, Sublime Text,Jupyter',
#        ' Sublime Text', 'Jupyter  ,PyCharm , Spyder, Notepad++,Jupyter',
#        'RStudio ,Visual Studio , Spyder,Jupyter',
#        'Jupyter  ,Visual Studio ,PyCharm ',
#        'RStudio ,Visual Studio ,Visual Studio Code  ,PyCharm ',
#        'RStudio ,PyCharm ,MATLAB ,Jupyter',
#        'Jupyter  ,PyCharm , Spyder, Sublime Text',
#        'RStudio ,Visual Studio Code  ,PyCharm , Notepad++,Jupyter',
#        'Jupyter  ,PyCharm , Spyder, Notepad++, Sublime Text',
#        'Visual Studio ,Visual Studio Code  , Other',
#        'Visual Studio ,PyCharm , Notepad++, Vim / Emacs,Jupyter',
#        'Jupyter  ,PyCharm , Notepad++, Vim / Emacs,Jupyter',
#        'RStudio , Spyder, Notepad++',
#        'Jupyter  , Notepad++,Jupyter, Other',
#        'Jupyter  ,PyCharm , Notepad++',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Spyder, Notepad++, Vim / Emacs',
#        'Visual Studio ,PyCharm , Notepad++,MATLAB ',
#        'Jupyter  ,MATLAB ,Jupyter', 'Visual Studio Code  ,MATLAB ',
#        'RStudio , Other',
#        'RStudio ,Visual Studio , Notepad++, Sublime Text, Vim / Emacs,Jupyter',
#        ' Spyder, Notepad++, Sublime Text',
#        'RStudio ,PyCharm , Sublime Text, Vim / Emacs,Jupyter',
#        'Visual Studio ,Visual Studio Code  ,MATLAB ,Jupyter',
#        'Visual Studio ,MATLAB ', 'PyCharm ,MATLAB ,Jupyter',
#        'Jupyter  ,PyCharm , Notepad++,MATLAB ',
#        'Visual Studio Code  , Notepad++, Sublime Text, Other',
#        'Visual Studio ,Visual Studio Code  ,PyCharm , Sublime Text',
#        'Visual Studio Code  , Spyder',
#        'Jupyter  ,Visual Studio ,MATLAB ,Jupyter',
#        ' Notepad++,Jupyter, Other',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Notepad++,Jupyter',
#        'Visual Studio Code  , Spyder, Sublime Text,Jupyter',
#        'RStudio ,Visual Studio Code  ,PyCharm , Notepad++,Jupyter, Other',
#        'RStudio , Sublime Text',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Sublime Text',
#        'PyCharm , Vim / Emacs,Jupyter',
#        'Jupyter  ,Visual Studio ,Jupyter',
#        'Jupyter  , Notepad++,MATLAB ,Jupyter',
#        'Visual Studio Code  , Vim / Emacs',
#        'Visual Studio Code  , Notepad++, Sublime Text,Jupyter',
#        'Jupyter  , Spyder, Sublime Text,Jupyter',
#        'PyCharm , Notepad++,MATLAB ', 'PyCharm , Notepad++, Other',
#        'RStudio , Spyder, Notepad++, Vim / Emacs,Jupyter',
#        'RStudio , Vim / Emacs',
#        'RStudio ,Visual Studio Code  , Sublime Text,Jupyter',
#        ' Notepad++, Vim / Emacs, Other',
#        'Visual Studio Code  ,PyCharm ,MATLAB ,Jupyter',
#        'Jupyter  ,RStudio ,Visual Studio ,PyCharm , Spyder,Jupyter',
#        'Visual Studio Code  , Notepad++,MATLAB ',
#        'RStudio ,Visual Studio Code  , Spyder,Jupyter',
#        'Visual Studio Code  , Sublime Text,Jupyter, Other',
#        ' Sublime Text, Vim / Emacs,MATLAB ,Jupyter',
#        'Visual Studio Code  , Sublime Text', 'RStudio , Spyder,MATLAB ',
#        'RStudio , Notepad++, Sublime Text, Vim / Emacs',
#        'RStudio ,Visual Studio ,Visual Studio Code  ,PyCharm , Notepad++, Sublime Text,MATLAB ,Jupyter',
#        'Jupyter  ,Visual Studio ,PyCharm ,Jupyter',
#        'Jupyter  , Spyder, Vim / Emacs,Jupyter',
#        'RStudio , Spyder,MATLAB ,Jupyter',
#        'RStudio , Sublime Text, Vim / Emacs,Jupyter',
#        'RStudio ,Visual Studio ,PyCharm , Spyder,Jupyter',
#        'Jupyter  ,PyCharm , Notepad++, Sublime Text, Vim / Emacs,Jupyter',
#        'Visual Studio ,Visual Studio Code  ,PyCharm , Sublime Text,Jupyter',
#        'Jupyter  ,RStudio ,PyCharm , Spyder,Jupyter',
#        'Jupyter  ,RStudio ,Visual Studio , Spyder,Jupyter',
#        'Jupyter  ,RStudio , Sublime Text,Jupyter',
#        'Jupyter  ,Visual Studio , Notepad++, Sublime Text,Jupyter',
#        ' Spyder, Sublime Text,Jupyter', ' Spyder,Jupyter, Other',
#        'Visual Studio Code  , Notepad++, Sublime Text',
#        'PyCharm , Notepad++, Vim / Emacs,MATLAB ,Jupyter',
#        'Visual Studio Code  , Sublime Text, Vim / Emacs',
#        'Visual Studio , Vim / Emacs,Jupyter',
#        'Jupyter  ,RStudio ,PyCharm ,MATLAB ',
#        'Visual Studio ,PyCharm ,Jupyter, Other',
#        'Visual Studio , Notepad++,Jupyter', 'Jupyter  , Vim / Emacs',
#        ' Notepad++,MATLAB ,Jupyter',
#        'RStudio ,Visual Studio ,Visual Studio Code  ,PyCharm , Spyder, Notepad++, Sublime Text,MATLAB ,Jupyter',
#        'Visual Studio ,PyCharm , Spyder,Jupyter',
#        'RStudio ,Visual Studio , Spyder, Notepad++',
#        'Jupyter  ,RStudio , Spyder, Notepad++, Sublime Text,Jupyter',
#        'Jupyter  ,RStudio ,PyCharm , Sublime Text,Jupyter',
#        'PyCharm , Notepad++, Sublime Text,MATLAB ,Jupyter',
#        'PyCharm , Notepad++, Sublime Text,Jupyter',
#        'Jupyter  ,RStudio ,Visual Studio ,PyCharm , Notepad++,Jupyter',
#        'RStudio ,Visual Studio ,PyCharm , Spyder, Notepad++,Jupyter',
#        'Visual Studio Code  , Vim / Emacs,Jupyter',
#        'RStudio ,Visual Studio ,PyCharm , Sublime Text,Jupyter',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Spyder,MATLAB ,Jupyter',
#        'Jupyter  ,RStudio , Other', 'Jupyter  ,RStudio , Vim / Emacs',
#        'Visual Studio ,Visual Studio Code  , Spyder, Notepad++,Jupyter',
#        'RStudio ,Visual Studio ,PyCharm , Spyder,MATLAB ,Jupyter',
#        'Jupyter  ,Visual Studio ,PyCharm , Spyder,Jupyter',
#        'RStudio , Spyder, Notepad++,MATLAB ,Jupyter',
#        'RStudio , Spyder, Other',
#        'Jupyter  ,PyCharm , Vim / Emacs,Jupyter',
#        'Jupyter  , Sublime Text,MATLAB ',
#        'RStudio , Spyder, Notepad++, Sublime Text,Jupyter',
#        'RStudio ,Visual Studio Code  , Spyder, Notepad++,Jupyter',
#        'PyCharm , Sublime Text, Vim / Emacs,MATLAB ,Jupyter',
#        'Jupyter  ,RStudio ,PyCharm , Sublime Text, Vim / Emacs,Jupyter',
#        'Visual Studio , Notepad++,MATLAB ,Jupyter',
#        'RStudio ,Visual Studio Code  , Other',
#        'Visual Studio ,Visual Studio Code  ,PyCharm , Spyder, Notepad++,Jupyter',
#        'RStudio ,Visual Studio Code  , Notepad++',
#        'RStudio ,PyCharm , Vim / Emacs,Jupyter',
#        'Visual Studio ,PyCharm ,MATLAB ,Jupyter',
#        'Jupyter  ,PyCharm , Sublime Text',
#        'RStudio , Vim / Emacs,Jupyter',
#        'RStudio ,Visual Studio Code  ,PyCharm , Spyder, Sublime Text,MATLAB ,Jupyter',
#        'Visual Studio , Notepad++, Other',
#        'RStudio ,PyCharm , Spyder, Sublime Text,Jupyter',
#        'Visual Studio Code  , Sublime Text,MATLAB ,Jupyter',
#        'Visual Studio Code  ,PyCharm , Vim / Emacs,Jupyter',
#        ' Vim / Emacs', 'Visual Studio Code  ,PyCharm , Sublime Text',
#        'Jupyter  ,RStudio ,Visual Studio ,PyCharm , Notepad++, Sublime Text,Jupyter',
#        ' Spyder, Notepad++,MATLAB ', 'RStudio ,PyCharm , Sublime Text',
#        'RStudio ,Visual Studio ,Visual Studio Code  ',
#        'Jupyter  , Spyder, Other', ' Sublime Text,MATLAB ',
#        'Jupyter  ,PyCharm , Spyder,Jupyter, Other',
#        'Jupyter  , Notepad++, Sublime Text,MATLAB , Other',
#        'Jupyter  , Spyder, Sublime Text,MATLAB ,Jupyter',
#        'Jupyter  ,RStudio ,Visual Studio ', 'Jupyter  , Spyder,MATLAB ',
#        'Jupyter  ,RStudio ,Visual Studio ,MATLAB ,Jupyter',
#        'Visual Studio Code  , Spyder,MATLAB ,Jupyter',
#        'RStudio ,Visual Studio Code  , Notepad++, Vim / Emacs,Jupyter',
#        'RStudio ,Visual Studio Code  ,PyCharm , Notepad++, Sublime Text, Vim / Emacs,Jupyter',
#        'RStudio ,Visual Studio , Notepad++, Other',
#        'PyCharm , Sublime Text, Other', 'Jupyter  ,PyCharm , Vim / Emacs',
#        'Jupyter  ,RStudio , Notepad++, Sublime Text',
#        'PyCharm , Spyder, Vim / Emacs,Jupyter',
#        'Jupyter  ,RStudio , Spyder, Notepad++, Vim / Emacs',
#        'Jupyter  ,Visual Studio ,PyCharm , Spyder, Sublime Text,Jupyter',
#        'Jupyter  ,RStudio ,Visual Studio ,PyCharm ,Jupyter',
#        'RStudio ,Visual Studio ,Visual Studio Code  , Notepad++, Vim / Emacs'],
#       dtype=object)

# %%
def crear_filas(df,patron,columna):
    """
    Esta función divide la respuesta de cada individuo separándola por comas y crea 1 fila por cada separación
    Args: 
    df(df):dataframe sobre el que queremos aplicar los cambios
    patron(string): es el patron por el que nuestra función nos va a hacer la separación
    columna(string): es el nombre de la columna sobre la que queremos aplicar nuestra función
    """
    
    df[columna] = df[columna].str.split(patron, n = -1)
       
    return df.explode(columna).reset_index(drop = True)

# %%
df = crear_filas(df, ",", "ides")

# %%
df
# Out:
#                        country  current_role yearly_compensation  \
# 0                      Belgium  Data Analyst         2,000-2,999
# 1                      Belgium  Data Analyst         2,000-2,999
# 2     United States of America  Data Analyst             unknown
# 3                        Egypt  Data Analyst         7,500-9,999
# 4                        Egypt  Data Analyst         7,500-9,999
# ...                        ...           ...                 ...
# 5135                     India  Data Analyst         3,000-3,999
# 5136                     India  Data Analyst         3,000-3,999
# 5137                     Egypt  Data Analyst       15,000-19,999
# 5138                     Egypt  Data Analyst       15,000-19,999
# 5139                     Egypt  Data Analyst       15,000-19,999
#
#               programming_languages          ides  \
# 0                       Python, SQL     Jupyter
# 1                       Python, SQL       Jupyter
# 2                                 R      RStudio
# 3                            Python     Notepad++
# 4                            Python       Jupyter
# ...                             ...           ...
# 5135                      Python, C      PyCharm
# 5136                      Python, C       Jupyter
# 5137  Python, SQL, Javascript, Bash     Jupyter
# 5138  Python, SQL, Javascript, Bash   Vim / Emacs
# 5139  Python, SQL, Javascript, Bash       Jupyter
#
#                                        visualization  \
# 0      Matplotlib ,Seaborn ,Plotly / Plotly Express
# 1      Matplotlib ,Seaborn ,Plotly / Plotly Express
# 2                                  Ggplot / ggplot2
# 3                                               None
# 4                                               None
# ...                                              ...
# 5135          Matplotlib ,Seaborn ,Ggplot / ggplot2
# 5136          Matplotlib ,Seaborn ,Ggplot / ggplot2
# 5137                            Matplotlib ,Seaborn
# 5138                            Matplotlib ,Seaborn
# 5139                            Matplotlib ,Seaborn
#
#                                              activities     gender  \
# 0     Analyze and understand data to influence produ...        Man
# 1     Analyze and understand data to influence produ...        Man
# 2                                               unknown  Nonbinary
# 3     Analyze and understand data to influence produ...      Woman
# 4     Analyze and understand data to influence produ...      Woman
# ...                                                 ...        ...
# 5135  Experimentation and iteration to improve exist...        Man
# 5136  Experimentation and iteration to improve exist...        Man
# 5137  Analyze and understand data to influence produ...        Man
# 5138  Analyze and understand data to influence produ...        Man
# 5139  Analyze and understand data to influence produ...        Man
#
#                                            primary_tool     ages
# 0     Local development environments (RStudio, Jupyt...  mediana
# 1     Local development environments (RStudio, Jupyt...  mediana
# 2                                               unknown    joven
# 3     Basic statistical software (Microsoft Excel, G...  mediana
# 4     Basic statistical software (Microsoft Excel, G...  mediana
# ...                                                 ...      ...
# 5135                                            unknown  mediana
# 5136                                            unknown  mediana
# 5137  Business intelligence software (Salesforce, Ta...  mediana
# 5138  Business intelligence software (Salesforce, Ta...  mediana
# 5139  Business intelligence software (Salesforce, Ta...  mediana
#
# [5140 rows x 10 columns]

# %%
df["ides"].value_counts()
# Out:
# Jupyter                 1429
# RStudio                  563
# PyCharm                  538
# Jupyter                  466
# Visual Studio Code       452
#  Notepad++               386
#  Spyder                  337
# Visual Studio            270
#  Sublime Text            206
# unknown                  143
# MATLAB                   123
#  Other                   109
#  Vim / Emacs              66
#  None                     52
# Name: ides, dtype: int64

# %%
def limpieza(elemento):
    """
    Esta función nos permite eliminar los espacios que hay al principio y al final de los strings 
    Args: elementos
    elemento(string): es el dato al que le queremos quitar los espacios 
    """
    try:
        return elemento.strip()
         
    except:
        return elemento

# %%
df['ides'] = df['ides'].apply(limpieza)
df['ides'].unique()
# Out:
# array(['Jupyter', 'RStudio', 'Notepad++', 'PyCharm', 'MATLAB', 'Spyder',
#        'None', 'Other', 'Visual Studio', 'Sublime Text',
#        'Visual Studio Code', 'unknown', 'Vim / Emacs'], dtype=object)

# %%
df["ides"].value_counts()
# Out:
# Jupyter               1895
# RStudio                563
# PyCharm                538
# Visual Studio Code     452
# Notepad++              386
# Spyder                 337
# Visual Studio          270
# Sublime Text           206
# unknown                143
# MATLAB                 123
# Other                  109
# Vim / Emacs             66
# None                    52
# Name: ides, dtype: int64

# %%
ordenado = df['ides'].value_counts().sort_values(ascending = False).head()
ordenado_desc = pd.DataFrame(ordenado).reset_index()

# %%
ordenado_desc
# Out:
#                 index  ides
# 0             Jupyter  1895
# 1             RStudio   563
# 2             PyCharm   538
# 3  Visual Studio Code   452
# 4           Notepad++   386

# %%
plt.figure(figsize =(10,5))
sns.barplot(y = "index", x = "ides", data = ordenado_desc, palette="crest");
plt.title("Los 5 ides más utilizados", color = "pink", fontweight='bold', fontsize = 16);
plt.xlabel("ides", color = "#3a6670");
plt.ylabel("count", color = "#3a6670");
#fig.tight_layout()
